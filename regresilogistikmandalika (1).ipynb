# %%
#import library
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import seaborn as sn
import matplotlib.pyplot as plt
from google.colab import files 
filenya = files.upload()
# Out:
#      <input type="file" id="files-82c6c13b-8ea8-4877-b3e8-f262059c7e16" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82c6c13b-8ea8-4877-b3e8-f262059c7e16">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Kuisioner Mandalika (Responses) - Form Responses 6.csv to Kuisioner Mandalika (Responses) - Form Responses 6.csv

# %%
#read dataset
import io 
df = pd.read_csv(io.StringIO(filenya['Kuisioner Mandalika (Responses) - Form Responses 6.csv'].decode('utf-8')))
df.head(38)
# Out:
#                           Nama               Status  Umur  Jenis Kelamin  \
# 0                        Vinca  Mahasiswa/Mahasiswi     20     Perempuan
# 1          Gregorius Aldonis K  Mahasiswa/Mahasiswi     21     Laki-Laki
# 2   Devani Putri Rizki Yuliani  Mahasiswa/Mahasiswi     20     Perempuan
# 3                         Ryan  Mahasiswa/Mahasiswi     20     Laki-Laki
# 4                        Gavra  Mahasiswa/Mahasiswi     22     Laki-Laki
# 5               zefanya ardika  Mahasiswa/Mahasiswi     20     Laki-Laki
# 6                       Nirin               Pekerja     25     Perempuan
# 7           arya damar pratama  Mahasiswa/Mahasiswi     21     Laki-Laki
# 8      Noviolen Jehovan Dieksa  Mahasiswa/Mahasiswi     18     Laki-Laki
# 9                     Kireina   Mahasiswa/Mahasiswi     21     Perempuan
# 10                     Susanah              Pekerja     54     Perempuan
# 11                      Selena  Mahasiswa/Mahasiswi     21     Perempuan
# 12                Rico Rantung  Mahasiswa/Mahasiswi     22     Laki-Laki
# 13                        Dika  Mahasiswa/Mahasiswi     23     Laki-Laki
# 14           Natania Desyderia  Mahasiswa/Mahasiswi     22     Perempuan
# 15                Nurul Fitri   Mahasiswa/Mahasiswi     22     Perempuan
# 16                      Nicki     Mencari pekerjaan     23     Laki-Laki
# 17                        Anza  Mahasiswa/Mahasiswi     21     Laki-Laki
# 18                Angel Meylia  Mahasiswa/Mahasiswi     21     Perempuan
# 19                       Tommy  Mahasiswa/Mahasiswi     20     Laki-Laki
# 20           Dwi Rizki Saputra  Mahasiswa/Mahasiswi     20     Laki-Laki
# 21   Yosep Andito Argha Kusuma  Mahasiswa/Mahasiswi     19     Laki-Laki
# 22            Chandra Setyawan  Mahasiswa/Mahasiswi     21     Laki-Laki
# 23                      barbie  Mahasiswa/Mahasiswi     22     Perempuan
# 24  Dion Permana Putra Landusa  Mahasiswa/Mahasiswi     22     Laki-Laki
# 25                        Fika  Mahasiswa/Mahasiswi     21     Perempuan
# 26          Gianina Dea Aneria  Mahasiswa/Mahasiswi     19     Perempuan
# 27        Sinatria Banyu Adil   Mahasiswa/Mahasiswi     21     Laki-Laki
# 28            Aditya Cornelius  Mahasiswa/Mahasiswi     25     Laki-Laki
# 29                     Stefani  Mahasiswa/Mahasiswi     19     Perempuan
# 30                         Fio  Mahasiswa/Mahasiswi     21     Perempuan
# 31            William Kendrick  Mahasiswa/Mahasiswi     21     Laki-Laki
# 32        Vernaldy Revimaputra  Mahasiswa/Mahasiswi     21     Laki-Laki
# 33                     Noversa  Mahasiswa/Mahasiswi     20     Laki-Laki
# 34                     Purnama  Mahasiswa/Mahasiswi     22     Laki-Laki
# 35   Kimi Sebastian Juliansyah  Mahasiswa/Mahasiswi     19     Laki-Laki
# 36                      Annisa  Mahasiswa/Mahasiswi     22     Perempuan
# 37                         ica              Pelajar     21     Perempuan
#
#     Tanya1  Tanya2  Tanya3  Tanya4  Tanya5  Tanya6  Tanya7  Hasil
# 0      100     100     100     100      50     100     100      1
# 1      100     100     100     100      50     100     100      1
# 2      100     100     100     100      50     100     100      1
# 3      100     100     100     100     100     100     100      1
# 4      100     100     100     100      50     100     100      1
# 5      100     100     100     100      50     100     100      1
# 6      100     100     100     100      50     100     100      1
# 7      100     100     100     100      50     100     100      1
# 8      100     100     100     100      50     100     100      1
# 9      100      50      50      50      50      50     100      0
# 10     100     100     100     100      50     100     100      1
# 11     100     100     100     100      50     100     100      1
# 12     100     100     100     100      50     100     100      1
# 13     100     100     100     100      50     100     100      1
# 14     100     100     100     100      50     100     100      1
# 15     100     100     100     100      50     100     100      1
# 16     100     100     100     100      50     100     100      1
# 17     100     100     100     100     100     100     100      1
# 18     100     100     100     100      50     100     100      1
# 19     100     100     100     100     100     100     100      1
# 20      50     100     100      50     100      50     100      0
# 21     100     100     100     100      50     100     100      1
# 22     100     100     100     100      50     100     100      1
# 23     100      50      50     100      50      50     100      0
# 24     100     100     100     100      50     100     100      1
# 25     100     100     100      50      50     100     100      1
# 26     100     100     100     100      50     100     100      1
# 27     100     100     100     100     100     100     100      1
# 28      50      50      50      50      50      50     100      0
# 29     100     100     100     100      50     100     100      1
# 30     100      50     100     100     100     100     100      1
# 31     100     100     100     100      50     100     100      1
# 32     100     100     100      50     100     100     100      1
# 33     100     100     100     100      50     100     100      1
# 34      50     100      50     100     100     100     100      1
# 35     100     100      50      50      50      50     100      0
# 36     100     100     100     100      50     100     100      1
# 37      50     100     100     100      50      50     100      0

# %%
#Showing row and column
df.shape
# Out:
# (38, 12)

# %%
#Showing all column
df.columns
# Out:
# Index(['Nama', ' Status', 'Umur ', 'Jenis Kelamin', 'Tanya1', 'Tanya2',
#        'Tanya3', 'Tanya4', 'Tanya5', 'Tanya6', 'Tanya7', 'Hasil'],
#       dtype='object')

# %%
#set up variabel independen as x an y as variabel dependen
X = df[['Tanya1','Tanya2','Tanya3', 'Tanya4', 'Tanya5', 'Tanya6', 'Tanya7']]
y = df['Hasil']

# %%
#set up train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
#apply logistic regresion formula
logistic_regression = LogisticRegression(solver='liblinear')
logistic_regression.fit(X_train, y_train)
y_pred = logistic_regression.predict(X_test)

# %%
#apply Confusion Matrix
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sn.heatmap(confusion_matrix, annot=True)

# %%
#show accuracy preccision recall result
print('Accuracy: ', metrics.accuracy_score(y_test, y_pred))
plt.show() 

#TP = True Positive = 9
TP = 8
#TN = Benar Negatif = 1
TN = 2
#FP = Positif Salah = 0
FP = 2
#FN = Negatif Salah =0
FN = 1
#Anda bisa mendapatkan Akurasi menggunakan:
#Ingat bahwa dataset asli (dari langkah 1) memiliki 38 pengamatan. Karena kita menetapkan ukuran pengujian ke 0,25, maka confusion matrix menampilkan hasil untuk 10 baris (= 38 * 0,25). Berikut ini adalah 10 baris uji:
#Akurasi = (TP + TN) / Total = 9 +0) / 10 = 0,9 merupakan rasio prediksi Benar (positif dan negatif) dengan keseluruhan data.
#Oleh karena itu akurasi adalah 70% untuk set tes.

#Precission = (TP) / (TP+FP) merupakan rasio prediksi benar positif dibandingkan dengan keseluruhan hasil yang diprediksi positf.
print('Precision :', (TP)/TP+FP) 

#Recall = (TP) / (TP + FN) merupakan rasio prediksi benar positif dibandingkan dengan keseluruhan data yang benar positif.
print('Recall :', (TP) / (TP + FN))

#Specificity = (TN)/ (TN + FP) merupakan kebenaran memprediksi negatif dibandingkan dengan keseluruhan data negatif.
print('Specifiicity :', (TN)/ (TN + FP))

#F1 Score = 2 * (Recall*Precission) / (Recall + Precission) F1 Score merupakan perbandingan rata-rata presisi dan recall yang dibobotkan
print('F1 Score :', 2 * (0.8 * 3.0) / (0.8 + 3.0))
# Out:
# Accuracy:  1.0
# Precision : 3.0
# Recall : 0.8888888888888888
# Specifiicity : 0.5
# F1 Score : 1.2631578947368423

# %%
print(X_test) #test dataset
print(y_pred) #predicted values
# Out:
#     Tanya1  Tanya2  Tanya3  Tanya4  Tanya5  Tanya6  Tanya7
# 22     100     100     100     100      50     100     100
# 29     100     100     100     100      50     100     100
# 16     100     100     100     100      50     100     100
# 15     100     100     100     100      50     100     100
# 11     100     100     100     100      50     100     100
# 20      50     100     100      50     100      50     100
# 26     100     100     100     100      50     100     100
# 10     100     100     100     100      50     100     100
# 25     100     100     100      50      50     100     100
# 2      100     100     100     100      50     100     100
# [1 1 1 1 1 0 1 1 1 1]

# %%
accuracyScore = metrics.accuracy_score(y_test,y_pred)
print('Accuracy score : ', accuracyScore)
print("Accuracy in Percentage : ", int(accuracyScore*100),'%')
# Out:
# Accuracy score :  1.0
# Accuracy in Percentage :  100 %
